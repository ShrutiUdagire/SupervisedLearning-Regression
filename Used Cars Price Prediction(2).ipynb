# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Shruti Udagire\\Machine Learning\\Practice\\Used car -2.csv")
df=df.sample(frac=1,random_state=1)
df.drop('Unnamed: 0',axis=1,inplace=True)
df
# Out:
#                                      Name    Location  Year  \
# 2319               Fiat Linea 1.3 Emotion       Kochi  2016
# 3652            BMW X1 M Sport sDrive 20d      Mumbai  2016
# 2397         Honda City Corporate Edition      Mumbai  2012
# 3536            Ford Figo Diesel Titanium   Hyderabad  2014
# 4400  Mercedes-Benz GLC 220d 4MATIC Sport      Mumbai  2017
# ...                                   ...         ...   ...
# 905            Tata Tiago 1.2 Revotron XZ   Hyderabad  2017
# 5192        Hyundai i20 1.2 Sportz Option       Kochi  2014
# 3980                 Honda City i VTEC SV      Mumbai  2016
# 235   Mercedes-Benz GLC 220d 4MATIC Style      Mumbai  2017
# 5157               Mahindra XUV500 W8 2WD  Coimbatore  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 2319              56628    Diesel       Manual      First   20.4 kmpl
# 3652              31000    Diesel    Automatic      First  17.05 kmpl
# ...

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            5195
# Price                   0
# dtype: int64

# %%
#Droping New_price colums
df.drop('New_Price',axis=1,inplace=True)
df
# Out:
#                                      Name    Location  Year  \
# 2319               Fiat Linea 1.3 Emotion       Kochi  2016
# 3652            BMW X1 M Sport sDrive 20d      Mumbai  2016
# 2397         Honda City Corporate Edition      Mumbai  2012
# 3536            Ford Figo Diesel Titanium   Hyderabad  2014
# 4400  Mercedes-Benz GLC 220d 4MATIC Sport      Mumbai  2017
# ...                                   ...         ...   ...
# 905            Tata Tiago 1.2 Revotron XZ   Hyderabad  2017
# 5192        Hyundai i20 1.2 Sportz Option       Kochi  2014
# 3980                 Honda City i VTEC SV      Mumbai  2016
# 235   Mercedes-Benz GLC 220d 4MATIC Style      Mumbai  2017
# 5157               Mahindra XUV500 W8 2WD  Coimbatore  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 2319              56628    Diesel       Manual      First   20.4 kmpl
# 3652              31000    Diesel    Automatic      First  17.05 kmpl
# ...

# %%
df.describe(include='all')
# Out:
#                           Name Location         Year  Kilometers_Driven  \
# count                     6019     6019  6019.000000       6.019000e+03
# unique                    1876       11          NaN                NaN
# top     Mahindra XUV500 W8 2WD   Mumbai          NaN                NaN
# freq                        49      790          NaN                NaN
# mean                       NaN      NaN  2013.358199       5.873838e+04
# std                        NaN      NaN     3.269742       9.126884e+04
# min                        NaN      NaN  1998.000000       1.710000e+02
# 25%                        NaN      NaN  2011.000000       3.400000e+04
# 50%                        NaN      NaN  2014.000000       5.300000e+04
# 75%                        NaN      NaN  2016.000000       7.300000e+04
# max                        NaN      NaN  2019.000000       6.500000e+06
#
#        Fuel_Type Transmission Owner_Type    Mileage   Engine   Power  \
# ...

# %%
df[(df['Power']=='null bhp')]
#  SPlitting the data so as to convert it to float
list1=['Mileage','Engine','Power']
for j in list1:
    list2=[]
    for i in df[j]:
        i=i.split(" ")[0]
        if(i=='null'):
            i='0.0'
        list2.append(i)
    df[j]=list2 

#COnverting to float 
for i in list1:      
    df[i]=df[i].astype(float)
df['Price']=df['Price'].astype(float)

# %% [markdown]
# # Dataset has values that have '0' or 'null'.

# %%
df[(df['Power']==0.0)]
# Out:
#                                      Name    Location  Year  \
# 687                  Toyota Etios Liva GD  Coimbatore  2013
# 3408                Maruti Swift VDI BSIV   Hyderabad  2014
# 2537                    Maruti Estilo LXI     Chennai  2008
# 3761                Maruti Swift VDI BSIV        Pune  2013
# 611   Hyundai Santro Xing XO eRLX Euro II        Pune  2006
# ...                                   ...         ...   ...
# 5045                      Toyota Etios GD  Coimbatore  2013
# 2468               Hyundai Santro Xing XO   Hyderabad  2007
# 2674                  Nissan Micra Diesel      Jaipur  2011
# 3606               Toyota Qualis Fleet A3      Mumbai  2001
# 1202                Maruti Swift VDI BSIV   Hyderabad  2016
#
#       Kilometers_Driven Fuel_Type Transmission      Owner_Type  Mileage  \
# 687               62601    Diesel       Manual           First    23.59
# 3408              81609    Diesel       Manual           First    17.80
# ...

# %%
df[(df['Mileage']==0.0)]
# Out:
#                                      Name    Location  Year  \
# 2372  Mercedes-Benz M-Class ML 350 4Matic   Bangalore  2014
# 4643               Hyundai Santro Xing GL   Hyderabad  2010
# 4525               Hyundai Santro Xing GL       Kochi  2011
# 2702            Hyundai Santro LP zipPlus  Coimbatore  2004
# 3179      Hyundai Santro GLS II - Euro II       Kochi  2012
# ...                                   ...         ...   ...
# 2770               Hyundai Santro Xing GL      Mumbai  2008
# 519        Hyundai Santro GLS I - Euro II      Jaipur  2009
# 806   Mercedes-Benz M-Class ML 350 4Matic   Bangalore  2015
# 3796       Hyundai Santro GLS I - Euro II  Coimbatore  2012
# 3606               Toyota Qualis Fleet A3      Mumbai  2001
#
#       Kilometers_Driven Fuel_Type Transmission      Owner_Type  Mileage  \
# 2372              33000    Diesel    Automatic          Second      0.0
# 4643              58163    Petrol       Manual           First      0.0
# ...

# %% [markdown]
# # Imputing those values

# %%
values=dict(list(df.groupby('Engine')))
for i in values:
    df2=pd.DataFrame()
    df2=values[i]
    df.loc[(df['Engine']==i) & (df['Mileage']==0.0),'Mileage']=df2.median()['Mileage']


for i in values:
    df2=pd.DataFrame()
    df2=values[i]
    df.loc[(df['Engine']==i) & (df['Power']==0.0),'Power']=df2.median()['Power']

# %%
df[(df['Mileage']==0.0) | (df['Power']==0.0)]
# Out:
#                                       Name   Location  Year  \
# 3111               Skoda Superb 3.6 V6 FSI  Hyderabad  2009
# 3388            Porsche Cayman 2009-2012 S  Hyderabad  2010
# 4579                    Fiat Siena 1.2 ELX     Jaipur  2001
# 4748                    Nissan Teana 230jM     Mumbai  2008
# 2801     Audi A4 3.2 FSI Tiptronic Quattro  Hyderabad  2012
# 1260                        Maruti 1000 AC  Hyderabad  1998
# 1136  Porsche Cayman 2009-2012 S tiptronic     Mumbai  2011
# 2631               Mahindra Jeep MM 540 DP    Chennai  2002
# 4633               Skoda Superb 3.6 V6 FSI  Hyderabad  2010
# 5229                     Fiat Petra 1.2 EL       Pune  2005
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 3111              53000    Petrol    Automatic      First     0.00  3597.0
# 3388              10000    Petrol       Manual      First     9.00  3436.0
# 4579              70000    Petrol       Manual      Third     7.75  1242.0
# ...

# %%
# Manually imputing these values
df.loc[(df['Name']=='Porsche Cayman 2009-2012 S tiptronic')  & (df['Power']==0.0),'Power']="325"
df.loc[(df['Name']=='Maruti 1000 AC')  & (df['Power']==0.0),'Power']="37"
df.loc[(df['Name']=='Mahindra Jeep MM 540 DP')  & (df['Power']==0.0),'Power']="62"
df.loc[(df['Name']=='Audi A4 3.2 FSI Tiptronic Quattro')  & (df['Power']==0.0),'Power']="255"
df.loc[(df['Name']=='Porsche Cayman 2009-2012 S')  & (df['Power']==0.0),'Power']="315"
df.loc[(df['Name']=='Fiat Siena 1.2 ELX')  & (df['Power']==0.0),'Power']="57"
df.loc[(df['Name']=='Nissan Teana 230jM')  & (df['Power']==0.0),'Power']="179.5"
df.loc[(df['Name']=='Fiat Petra 1.2 EL')  & (df['Power']==0.0),'Power']="57"
df.loc[(df['Name']=='Skoda Superb 3.6 V6 FSI')  & (df['Mileage']==0.0),'Mileage']="7.0"

# %%
df.drop(df[(df['Mileage']==0.0) | (df['Power']==0.0)].index,axis=0,inplace=True)

# %%
df[(df['Mileage']==0.0) | (df['Power']==0.0)]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, Price]
# Index: []

# %% [markdown]
# # Completed droping / imputing missing values

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # WORKING WITH OULIERS

# %%
sns.distplot(df['Price'])

# %%
# df['Price']=df['Price'].apply(np.log)

# %%
# sns.distplot(df['Price'])

# %%
from scipy.stats import boxcox
df['Price'],lambda_value=boxcox(df['Price'])

# %%
sns.distplot(df['Price'])

# %%
sns.boxplot(df['Price'])

# %% [markdown]
# # Changing categorical values to numeric

# %%
df_dummies=pd.get_dummies(df[["Transmission","Fuel_Type"]],drop_first=True)
df=pd.concat([df_dummies,df],axis=1)

# as it is ordinal data
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['Owner_Type']= label_encoder.fit_transform(df['Owner_Type'])

# %%
df.drop(["Transmission","Fuel_Type","Name","Location"],axis=1,inplace=True)

# %%
df['Mileage']=df['Mileage'].astype(float)
df['Power']=df['Power'].astype(float)
df['Seats']=df['Seats'].astype(int)

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# From heatmap-1)Fuel_Type_petrol is positively correlated with Fuel_Type_Diesel
#               2)Transmission_manual and Price are highly correlated

# %%
df.drop('Fuel_Type_Petrol',axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
for i in df:
    sns.scatterplot(df[i],df['Price'])
    plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.xticks(np.arange(1998,2020))
sns.scatterplot(df['Year'],df['Price'],hue=df['Owner_Type'])

# %% [markdown]
# The cars that have been been launched after the year 2010 are more as compartively before 2010
# The prices of car that have launched after the year 2010 are more.
# We have more number of cars that are second hand that is of owner type 1

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.xticks(np.arange(0,600,50))
sns.scatterplot(df['Power'],df['Price'],hue=df['Owner_Type'])

# %% [markdown]
# The car with higher power tends to have higher price

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.xticks(np.arange(0,11,1))
sns.boxplot(df['Transmission_Manual'],df['Price'])

# %%
df['Transmission_Manual'].value_counts()
# Out:
# 1    4298
# 0    1720
# Name: Transmission_Manual, dtype: int64

# %% [markdown]
#  The cars that have automatic transmission are more with compared to  cars having manual transmission.
#  AS well as cars with automatic transmission have a higher range of Price

# %% [markdown]
# # Splitting in train Validation and scaling X

# %%
from scipy.stats import zscore
X=df.drop('Price',axis=1)
y=df['Price']
X=X.apply(zscore)

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape,X_validation.shape,y_train.shape,y_validation.shape
# Out:
# ((4032, 11), (1986, 11), (4032,), (1986,))

# %% [markdown]
# # Linear Model -OLS

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant = sm.add_constant(X_train)
lin_reg = sm.OLS(y_train,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     2312.
# Date:                Fri, 27 Mar 2020   Prob (F-statistic):               0.00
# Time:                        23:05:20   Log-Likelihood:                 50.946
# No. Observations:                4032   AIC:                            -77.89
# Df Residuals:                    4020   BIC:                            -2.268
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_train, lin_reg.predict())
rmse=np.sqrt(mse)
rmse
# Out:
# 0.23893254551765758

# %%
X.drop(['Fuel_Type_LPG','Owner_Type','Engine','Fuel_Type_Electric'],axis=1,inplace=True)
# Dropping Fuel_Type_Electric because in test data we dnt get a dummy named as 'Fuel_Type_Electric'
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant = sm.add_constant(X_train)
lin_reg = sm.OLS(y_train,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     3488.
# Date:                Fri, 27 Mar 2020   Prob (F-statistic):               0.00
# Time:                        23:05:20   Log-Likelihood:                -21.686
# No. Observations:                4032   AIC:                             59.37
# Df Residuals:                    4024   BIC:                             109.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_train, lin_reg.predict())
rmse=np.sqrt(mse)
rmse
# Out:
# 0.24327568120654455

# %% [markdown]
# # Assumptions of linear Regression

# %%
# 1)No AutoCorrelation
import statsmodels.tsa.api as smt

acf = smt.graphics.plot_acf(lin_reg.resid, lags=40 , alpha=0.05)
acf.show()

# %% [markdown]
# As Durbin-Watson:1.991
#     It Means No AutoCorrelation

# %%
# 2)Homoskedaticity

# %%
# Predicted VS Residuals
sns.regplot(x=lin_reg.predict(), y=lin_reg.resid, lowess=True, line_kws={'color': 'red'})

# %%
# goldfeldquandt
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(lin_reg.resid, lin_reg.model.exog)
lzip(name, test)
# Out:
# [('F statistic', 1.005983917810566), ('p-value', 0.44683748690415137)]

# %% [markdown]
# H0:Residuals are homoskedatic in nature
#
#
# H1:Residuals are not homoskedatic in nature
#
# Pvalue>0.05.
#
#
# We fail to reject Null hypothesis

# %% [markdown]
# # DOUBT OF NORMALITY

# %%
# 2)Normality
# DOUBT
name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
test = sms.jarque_bera(lin_reg.resid)
lzip(name, test)
# Out:
# [('Jarque-Bera', 10725.196510638478),
#  ('Chi^2 two-tail prob.', 0.0),
#  ('Skew', -0.8915135626625583),
#  ('Kurtosis', 10.788534502126955)]

# %%
import seaborn as sns
sns.distplot(lin_reg.resid)

# %%
import scipy.stats as stats
import pylab
from statsmodels.graphics.gofplots import ProbPlot
stats.probplot(lin_reg.resid, dist="norm", plot = pylab)
plt.show()

# %%
# 4)Linearity

# %%
sns.regplot(x=lin_reg.predict(), y=y_train, lowess=True,  line_kws={'color': 'red'})

# %%
import statsmodels.api as sm
sm.stats.diagnostic.linear_rainbow(lin_reg, frac=0.5)
# Out:
# (1.0795047224594876, 0.04314786370603699)

# %% [markdown]
# H0:Residuals are Linear
#
# H1:residuals are not Linear
#
# pvalue>0.05
#
# hence Fail to Reject Null Hypothesis
#
# Hence Residuals are Linear

# %%
# 5) No multicollineratity
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X_constant.values, i) for i in range(X_constant.shape[1])]
pd.DataFrame({'vif': vif[1:]}, index=X.columns).T
# Out:
#      Transmission_Manual  Fuel_Type_Diesel      Year  Kilometers_Driven  \
# vif             1.814625          1.583026  1.557284           1.530519
#
#       Mileage    Power     Seats
# vif  2.058608  2.47198  1.445251

# %% [markdown]
# All Values are below 5.
#
# Hence there is No multicollineratity

# %%
# X_test_constant = sm.add_constant(X_test)
# X_test_constant

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant = sm.add_constant(X_train)
lin_reg = sm.OLS(y_train,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     3488.
# Date:                Fri, 27 Mar 2020   Prob (F-statistic):               0.00
# Time:                        23:05:39   Log-Likelihood:                -21.686
# No. Observations:                4032   AIC:                             59.37
# Df Residuals:                    4024   BIC:                             109.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_train, lin_reg.predict())
rmse=np.sqrt(mse)
rmse
# Out:
# 0.24327568120654455

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df1=pd.DataFrame()
df1['Predictions']=lr.predict(X_train)
df1['Predictions']=df1['Predictions'].apply(np.exp)
df1['Predictions']
# Out:
# 0        3.302503
# 1        3.497053
# 2        2.421738
# 3       18.269063
# 4        3.673723
#           ...
# 4027    10.730738
# 4028     1.615744
# 4029     3.798142
# 4030     1.747469
# 4031     2.966751
# Name: Predictions, Length: 4032, dtype: float64

# %%
sns.regplot(y_train,lr.predict(X_train),line_kws={'color': 'red'})

# %%
# X_test['const']=1.0

# %%
# X_test=X_test[['const','Transmission_Manual','Fuel_Type_Diesel','Fuel_Type_Electric','Year','Kilometers_Driven','Mileage','Power','Seats']]

# %%
df2=pd.DataFrame()
df2['Predictions']=lr.predict(X_validation)
df2['Predictions']=df2['Predictions'].apply(np.exp)
df2['Predictions']
# Out:
# 0        4.162313
# 1       19.622088
# 2        3.546904
# 3        3.099858
# 4        8.941145
#           ...
# 1981     8.536444
# 1982     1.829232
# 1983     4.664740
# 1984     4.782934
# 1985    10.751797
# Name: Predictions, Length: 1986, dtype: float64

# %%
sns.regplot(y_validation,lr.predict(X_validation),line_kws={'color': 'red'})

# %%
print(lr.score(X_train, y_train))
print(lr.score(X_validation, y_validation))
# Out:
# 0.8585169854948475
# 0.8452651728020698

# %% [markdown]
# # Loading Test data

# %%
df_test=pd.read_csv("C:\\Users\\Shruti Udagire\\Machine Learning\\Files\\car-test-data.csv")
df_test=df_test.dropna(axis=0)

# %%
df_test.drop(['Unnamed: 0','Name','Location','New_Price'],axis=1,inplace=True)

# %% [markdown]
# # Applying all transformation on test data

# %%
df_test
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 2     2017              34000    Diesel       Manual      First  13.68 kmpl
# 30    2014              70000    Diesel       Manual     Second  23.59 kmpl
# 36    2017              13500    Petrol    Automatic      First  14.84 kmpl
# 39    2012              66889    Diesel    Automatic      First  22.48 kmpl
# 43    2018               4000    Petrol       Manual      First  15.41 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 1209  2016              41413    Diesel       Manual      First  27.28 kmpl
# 1212  2017              39015    Petrol       Manual      First   17.0 kmpl
# 1213  2018               6000    Petrol       Manual      First   16.0 kmpl
# 1216  2017              21380    Diesel       Manual      First   24.3 kmpl
# 1217  2018              23955    Petrol       Manual      First   18.6 kmpl
#
#        Engine       Power  Seats
# ...

# %%
#  SPlitting the data so as to convert it to float
list1=['Mileage','Engine','Power']
for j in list1:
    list2=[]
    for i in df_test[j]:
        i=i.split(" ")[0]
        list2.append(i)
    df_test[j]=list2 

#COnverting to float 
for i in list1:      
    df_test[i]=df_test[i].astype(float)
# df_test['Price']=df_test['Price'].astype(float)

# %%
df
# Out:
#       Transmission_Manual  Fuel_Type_Diesel  Fuel_Type_Electric  \
# 2319                    1                 1                   0
# 3652                    0                 1                   0
# 2397                    1                 0                   0
# 3536                    1                 1                   0
# 4400                    0                 1                   0
# ...                   ...               ...                 ...
# 905                     1                 0                   0
# 5192                    1                 0                   0
# 3980                    1                 0                   0
# 235                     0                 1                   0
# 5157                    1                 1                   0
#
#       Fuel_Type_LPG  Year  Kilometers_Driven  Owner_Type  Mileage  Engine  \
# 2319              0  2016              56628           0    20.40  1248.0
# ...

# %%
df_dummies=pd.get_dummies(df_test[["Transmission","Fuel_Type"]],drop_first=True)
df_test=pd.concat([df_dummies,df_test],axis=1)

# as it is ordinal data
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df_test['Owner_Type']= label_encoder.fit_transform(df_test['Owner_Type'])

# %%
df_test
# Out:
#       Transmission_Manual  Fuel_Type_Diesel  Fuel_Type_Petrol  Year  \
# 2                       1                 1                 0  2017
# 30                      1                 1                 0  2014
# 36                      0                 0                 1  2017
# 39                      0                 1                 0  2012
# 43                      1                 0                 1  2018
# ...                   ...               ...               ...   ...
# 1209                    1                 1                 0  2016
# 1212                    1                 0                 1  2017
# 1213                    1                 0                 1  2018
# 1216                    1                 1                 0  2017
# 1217                    1                 0                 1  2018
#
#       Kilometers_Driven Fuel_Type Transmission  Owner_Type  Mileage  Engine  \
# ...

# %%
df_test['Mileage']=df_test['Mileage'].astype(float)
df_test['Power']=df_test['Power'].astype(float)
df_test['Seats']=df_test['Seats'].astype(int)
df_test.drop(["Transmission","Fuel_Type"],axis=1,inplace=True)
df_test.drop(['Fuel_Type_Petrol','Owner_Type','Engine'],axis=1,inplace=True)

# %%
df_test=df_test.apply(zscore)

# %%
lr.predict(df_test)
# Out:
# array([2.06799227, 0.93834874, 1.72282687, 1.55980988, 1.65591895,
#        1.33312258, 1.16216783, 1.38021533, 1.87247976, 1.53097878,
#        1.34862795, 1.92776232, 1.30282299, 1.57827777, 2.24810527,
#        0.96132133, 1.3314061 , 2.5075677 , 0.42334333, 1.26488706,
#        1.92156056, 1.2458956 , 1.41069869, 2.80947903, 0.63658999,
#        0.93873763, 2.49979018, 1.58296296, 1.36134833, 1.99373201,
#        0.99329908, 1.53512308, 0.72090624, 2.6563    , 0.93617672,
#        1.23635123, 1.62228799, 1.74255385, 1.30455275, 0.75550383,
#        1.16288194, 2.01044629, 0.8848895 , 0.52969828, 0.86367047,
#        0.99970531, 3.23952441, 1.32742872, 1.19985477, 1.08844845,
#        2.03035477, 1.37766225, 0.73565698, 0.83562608, 2.36641876,
#        1.29426759, 1.68195155, 1.28637473, 1.22224278, 1.19219599,
#        1.70222512, 1.78007069, 1.47153807, 1.57174331, 2.26648864,
#        1.05877264, 2.57195294, 1.58316619, 1.96057859, 1.89954088,
# ...

# %%
ss
df3=pd.DataFrame()
df3['Predictions']=lr.predict(df_test)
df3['Predictions']=df3['Predictions'].apply(np.exp)
df3['Predictions']
# Out:
# 0      7.908928
# 1      2.555758
# 2      5.600338
# 3      4.757917
# 4      5.237891
#          ...
# 177    3.496284
# 178    4.627531
# 179    7.059818
# 180    4.782827
# 181    4.357676
# Name: Predictions, Length: 182, dtype: float64
